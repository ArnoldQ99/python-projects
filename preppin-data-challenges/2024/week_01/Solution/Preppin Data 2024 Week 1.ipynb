# %% [markdown]
# Requirements
#
# 1. Input the data
# 2. Split the Flight Details field to form: Date, Flight Number, From, To, Class, Price
# 3. Convert the following data fields to the correct data types: Date to a date format, Price to a decimal value
# 4. Change the Flow Card field to Yes / No values instead of 1 / 0
# 5. Create two tables, one for Flow Card holders and one for non-Flow Card holders
# 6. Output the data sets

# %%
import pandas as pd

# %%
df = pd.read_csv('Preppin Data Inputs/PD 2024 Wk 1 Input.csv')

# %%
df
# Out:
#                                          Flight Details  Flow Card?  \
# 0      2024-07-22//PA010//Tokyo-New York//Economy//2380           1
# 1      2024-09-28//PA008//Perth-New York//Economy//1855           0
# 2     2024-04-20//PA002//New York-London//Economy//3490           1
# 3     2024-01-23//PA010//Tokyo-New York//Premium Eco...           1
# 4     2024-10-01//PA008//Perth-New York//Business Cl...           0
# ...                                                 ...         ...
# 3773   2024-05-05//PA009//New York-Tokyo//Economy//1360           0
# 3774  2024-06-14//PA008//Perth-New York//First Class...           0
# 3775   2024-01-16//PA010//Tokyo-New York//Economy//2410           0
# 3776  2024-08-16//PA005//London-Tokyo//Premium Econo...           0
# 3777  2024-01-06//PA004//Perth-London//First Class//236           1
#
#       Bags Checked   Meal Type
# 0                0    Egg Free
# 1                2  Vegetarian
# 2                1       Vegan
# 3                1  Vegetarian
# 4                0  Vegetarian
# ...            ...         ...
# 3773             3    Nut Free
# 3774             1  Dairy Free
# 3775             2    Egg Free
# 3776             0    Nut Free
# 3777             1    Nut Free
#
# [3778 rows x 4 columns]

# %%
# 2. Splitting the flight details field to form other fields

df['Date'] = df['Flight Details'].str.split('//').str[0]
df['Flight Number'] = df['Flight Details'].str.split('//').str[1]

df['To & From'] = df['Flight Details'].str.split('//').str[2]
df['To'] = df['To & From'].str.split('-').str[0]
df['From'] = df['To & From'].str.split('-').str[1]

df['Class'] = df['Flight Details'].str.split('//').str[3]
df['Price'] = df['Flight Details'].str.split('//').str[4]

df = df.drop('Flight Details', axis=1)
df = df.drop('To & From', axis=1)

# %%
df
# Out:
#       Flow Card?  Bags Checked   Meal Type        Date Flight Number  \
# 0              1             0    Egg Free  2024-07-22         PA010
# 1              0             2  Vegetarian  2024-09-28         PA008
# 2              1             1       Vegan  2024-04-20         PA002
# 3              1             1  Vegetarian  2024-01-23         PA010
# 4              0             0  Vegetarian  2024-10-01         PA008
# ...          ...           ...         ...         ...           ...
# 3773           0             3    Nut Free  2024-05-05         PA009
# 3774           0             1  Dairy Free  2024-06-14         PA008
# 3775           0             2    Egg Free  2024-01-16         PA010
# 3776           0             0    Nut Free  2024-08-16         PA005
# 3777           1             1    Nut Free  2024-01-06         PA004
#
#             To      From            Class               Price
# 0        Tokyo  New York          Economy                2380
# 1        Perth  New York          Economy                1855
# 2     New York    London          Economy                3490
# 3        Tokyo  New York  Premium Economy                 825
# 4        Perth  New York   Business Class  634.79999999999995
# ...        ...       ...              ...                 ...
# 3773  New York     Tokyo          Economy                1360
# 3774     Perth  New York      First Class                 245
# 3775     Tokyo  New York          Economy                2410
# 3776    London     Tokyo  Premium Economy                 960
# 3777     Perth    London      First Class                 236
#
# [3778 rows x 9 columns]

# %%
# 3. Convert the following data fields to the correct data types: Date to a date format, Price to a decimal value

df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df['Price'] = df['Price'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3778 entries, 0 to 3777
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Flow Card?     3778 non-null   int64
#  1   Bags Checked   3778 non-null   int64
#  2   Meal Type      3189 non-null   object
#  3   Date           3778 non-null   datetime64[ns]
#  4   Flight Number  3778 non-null   object
#  5   To             3778 non-null   object
#  6   From           3778 non-null   object
#  7   Class          3778 non-null   object
#  8   Price          3778 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 265.8+ KB

# %%
# 4. Change the Flow Card field to Yes / No values instead of 1 / 0

df['Flow Card?'] = df['Flow Card?'].apply(lambda x: 'Yes' if x == 1 else 'No')

# %%
df
# Out:
#      Flow Card?  Bags Checked   Meal Type       Date Flight Number        To  \
# 0           Yes             0    Egg Free 2024-07-22         PA010     Tokyo
# 1            No             2  Vegetarian 2024-09-28         PA008     Perth
# 2           Yes             1       Vegan 2024-04-20         PA002  New York
# 3           Yes             1  Vegetarian 2024-01-23         PA010     Tokyo
# 4            No             0  Vegetarian 2024-10-01         PA008     Perth
# ...         ...           ...         ...        ...           ...       ...
# 3773         No             3    Nut Free 2024-05-05         PA009  New York
# 3774         No             1  Dairy Free 2024-06-14         PA008     Perth
# 3775         No             2    Egg Free 2024-01-16         PA010     Tokyo
# 3776         No             0    Nut Free 2024-08-16         PA005    London
# 3777        Yes             1    Nut Free 2024-01-06         PA004     Perth
#
#           From            Class   Price
# 0     New York          Economy  2380.0
# 1     New York          Economy  1855.0
# 2       London          Economy  3490.0
# 3     New York  Premium Economy   825.0
# 4     New York   Business Class   634.8
# ...        ...              ...     ...
# 3773     Tokyo          Economy  1360.0
# 3774  New York      First Class   245.0
# 3775  New York          Economy  2410.0
# 3776     Tokyo  Premium Economy   960.0
# 3777    London      First Class   236.0
#
# [3778 rows x 9 columns]

# %%
# Create two tables, one for Flow Card holders and one for non-Flow Card holders

table1 = df[df['Flow Card?'] == 'Yes']
table2 = df[df['Flow Card?'] == 'No']

# %%
table1
# Out:
#      Flow Card?  Bags Checked   Meal Type       Date Flight Number        To  \
# 0           Yes             0    Egg Free 2024-07-22         PA010     Tokyo
# 2           Yes             1       Vegan 2024-04-20         PA002  New York
# 3           Yes             1  Vegetarian 2024-01-23         PA010     Tokyo
# 6           Yes             3       Vegan 2024-06-05         PA006     Tokyo
# 8           Yes             1    Nut Free 2024-03-30         PA004     Perth
# ...         ...           ...         ...        ...           ...       ...
# 3764        Yes             2    Egg Free 2024-11-23         PA005    London
# 3766        Yes             3    Nut Free 2024-11-04         PA003    London
# 3770        Yes             0  Dairy Free 2024-04-29         PA012     Tokyo
# 3772        Yes             2  Vegetarian 2024-09-26         PA001    London
# 3777        Yes             1    Nut Free 2024-01-06         PA004     Perth
#
#           From            Class   Price
# 0     New York          Economy  2380.0
# 2       London          Economy  3490.0
# 3     New York  Premium Economy   825.0
# 6       London      First Class   618.0
# 8       London      First Class   446.0
# ...        ...              ...     ...
# 3764     Tokyo          Economy  2070.0
# 3766     Perth      First Class   210.0
# 3770     Perth          Economy  3490.0
# 3772  New York      First Class   207.0
# 3777    London      First Class   236.0
#
# [1883 rows x 9 columns]

# %%
table2
# Out:
#      Flow Card?  Bags Checked   Meal Type       Date Flight Number        To  \
# 1            No             2  Vegetarian 2024-09-28         PA008     Perth
# 4            No             0  Vegetarian 2024-10-01         PA008     Perth
# 5            No             3    Nut Free 2024-03-04         PA007  New York
# 7            No             0         NaN 2024-02-25         PA010     Tokyo
# 13           No             2       Vegan 2024-03-29         PA004     Perth
# ...         ...           ...         ...        ...           ...       ...
# 3771         No             2  Vegetarian 2024-03-06         PA006     Tokyo
# 3773         No             3    Nut Free 2024-05-05         PA009  New York
# 3774         No             1  Dairy Free 2024-06-14         PA008     Perth
# 3775         No             2    Egg Free 2024-01-16         PA010     Tokyo
# 3776         No             0    Nut Free 2024-08-16         PA005    London
#
#           From            Class   Price
# 1     New York          Economy  1855.0
# 4     New York   Business Class   634.8
# 5        Perth   Business Class   458.4
# 7     New York  Premium Economy  1435.0
# 13      London          Economy  2730.0
# ...        ...              ...     ...
# 3771    London  Premium Economy   940.0
# 3773     Tokyo          Economy  1360.0
# 3774  New York      First Class   245.0
# 3775  New York          Economy  2410.0
# 3776     Tokyo  Premium Economy   960.0
#
# [1895 rows x 9 columns]

# %%
# 6. Output the datasets

table1.to_csv('Preppin Data Outputs/pd2024wk1_output1.csv', index=False)
table2.to_csv('Preppin Data Outputs/pd2024wk1_output2.csv', index=False)
