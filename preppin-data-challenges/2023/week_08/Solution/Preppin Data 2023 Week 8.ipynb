# %% [markdown]
# Requirements
#
# 1. Input each of the 12 monthly files
# 2. Create a 'file date' using the month found in the file name. The Null value should be replaced as 1
# 3. Clean the Market Cap value to ensure it is the true value as 'Market Capitalisation'. Remove any rows with 'n/a'
# 4. Categorise the Purchase Price into groupings: 0 to 24,999.99 as 'Low', 25,000 to 49,999.99 as 'Medium', 50,000 to 74,999.99 as 'High', 75,000 to 100,000 as 'Very High'
# 5. Categorise the Market Cap into groupings: Below 100M as 'Small', Between 100M and below 1B as 'Medium', Between 1B and below 100B as 'Large', 100B and above as 'Huge'
# 6. Rank the highest 5 purchases per combination of: file date, Purchase Price Categorisation and Market Capitalisation Categorisation.
# 7. Output only records with a rank of 1 to 5

# %%
import pandas as pd
import glob

# %% [markdown]
# 1. Input the 12 monthly files
# 2. Create a 'file date' using the month found in the file name. The Null value should be replaced as 1

# %%
csv = glob.glob('Preppin Data Inputs/Input/*.csv')

# %%
df_list = []

for file in csv:
    df = pd.read_csv(file)
    df['file date'] = file
    df_list.append(df)

# %%
df_list
# Out:
# [       id first_name   last_name     Ticker            Sector  Market  \
#  0       1      Hinze      Bartak      CYRXW    Transportation  NASDAQ
#  1       2      Lelia     Gresley       GILD       Health Care  NASDAQ
#  2       3  Leicester        Roff        NMZ               NaN    NYSE
#  3       4       Baxy     Fieller      USB^A           Finance    NYSE
#  4       5     Julita   Spradbery       INSI               NaN    NYSE
#  ..    ...        ...         ...        ...               ...     ...
#  995   996   Christel     Sarrell  CLNS^A.CL               NaN    NYSE
#  996   997       Rivi        Rame       EMCB               NaN  NASDAQ
#  997   998       Doti       Facer        SXT  Basic Industries    NYSE
#  998   999    Dorothy  Janauschek       KRNT     Capital Goods  NASDAQ
#  999  1000        Lin      Rosgen       GPAC       Health Care  NASDAQ
#
#                                            Stock Name Market Cap  \
#  0                                     CryoPort, Inc.        NaN
#  1                              Gilead Sciences, Inc.    $83.79B
#  2      Nuveen Municipal High Income Opportunity Fund   $794.98M
#  3                                       U.S. Bancorp        NaN
#  4                         Insight Select Income Fund   $211.52M
#  ..                                               ...        ...
#  995                           Colony NorthStar, Inc.        NaN
#  996  WisdomTree Emerging Markets Corporate Bond Fund    $50.49M
#  997                Sensient Technologies Corporation     $3.62B
#  998                              Kornit Digital Ltd.   $643.74M
#  999                 Global Partner Acquisition Corp.   $193.67M
#
#      Purchase Price                                file date
#  0         $6947.28  Preppin Data Inputs/Input/MOCK_DATA.csv
#  1        $77627.18  Preppin Data Inputs/Input/MOCK_DATA.csv
#  2        $40676.73  Preppin Data Inputs/Input/MOCK_DATA.csv
#  3        $42441.50  Preppin Data Inputs/Input/MOCK_DATA.csv
#  4        $41908.66  Preppin Data Inputs/Input/MOCK_DATA.csv
#  ..             ...                                      ...
#  995      $60683.35  Preppin Data Inputs/Input/MOCK_DATA.csv
#  996      $55605.12  Preppin Data Inputs/Input/MOCK_DATA.csv
#  997      $63432.98  Preppin Data Inputs/Input/MOCK_DATA.csv
#  998      $97859.28  Preppin Data Inputs/Input/MOCK_DATA.csv
#  999      $73954.07  Preppin Data Inputs/Input/MOCK_DATA.csv
#
#  [1000 rows x 10 columns],
#         id first_name  last_name Ticker                 Sector  Market  \
#  0       1      Mozes      Chape  XGTIW      Consumer Durables  NASDAQ
#  1       2   Nicoline    Kilalea   FCEL          Miscellaneous  NASDAQ
#  2       3  Andriette    Whitlam  FCH^A      Consumer Services    NYSE
#  3       4     Moreen        Say   SPXX                    NaN    NYSE
#  4       5    Haskell  Filchakov    TFX            Health Care    NYSE
#  ..    ...        ...        ...    ...                    ...     ...
#  995   996      Taite     Holdey   EARN      Consumer Services    NYSE
#  996   997   Benyamin     Fibbit    WCC  Consumer Non-Durables    NYSE
#  997   998       Arri     Maytom    TCS      Consumer Services    NYSE
#  998   999     Catlin    Clifton    HAL                 Energy    NYSE
#  999  1000      Ardis  Pickworth      G      Consumer Services    NYSE
#
#                                  Stock Name Market Cap Purchase Price  \
#  0                       XG Technology, Inc        NaN      $61242.80
#  1                    FuelCell Energy, Inc.    $65.53M      $20581.67
#  2        FelCor Lodging Trust Incorporated        NaN      $88251.56
#  3    Nuveen S&P 500 Dynamic Overwrite Fund    $250.2M      $76984.21
#  4                    Teleflex Incorporated     $9.03B      $69405.40
#  ..                                     ...        ...            ...
#  995    Ellington Residential Mortgage REIT   $140.16M      $24999.72
#  996              WESCO International, Inc.     $2.79B      $93583.48
#  997                  Container Store (The)   $277.68M      $19550.46
#  998                    Halliburton Company    $38.42B      $23474.77
#  999                        Genpact Limited     $5.21B      $54155.84
#
#                                        file date
#  0    Preppin Data Inputs/Input/MOCK_DATA-11.csv
#  1    Preppin Data Inputs/Input/MOCK_DATA-11.csv
#  2    Preppin Data Inputs/Input/MOCK_DATA-11.csv
#  3    Preppin Data Inputs/Input/MOCK_DATA-11.csv
#  4    Preppin Data Inputs/Input/MOCK_DATA-11.csv
#  ..                                          ...
#  995  Preppin Data Inputs/Input/MOCK_DATA-11.csv
#  996  Preppin Data Inputs/Input/MOCK_DATA-11.csv
#  997  Preppin Data Inputs/Input/MOCK_DATA-11.csv
#  998  Preppin Data Inputs/Input/MOCK_DATA-11.csv
#  999  Preppin Data Inputs/Input/MOCK_DATA-11.csv
#
#  [1000 rows x 10 columns],
#         id first_name     last_name Ticker             Sector  Market  \
#  0       1        Gay       Howgate    LUB  Consumer Services    NYSE
#  1       2      Shara        Kember    NRT             Energy    NYSE
#  2       3       Fawn        Hayers   RUBI         Technology    NYSE
#  3       4    Colette  Ricciardelli   PHMD        Health Care  NASDAQ
#  4       5    Collete    Kettlesing   EVAR        Health Care  NASDAQ
#  ..    ...        ...           ...    ...                ...     ...
#  995   996        Flo        Forton   OXFD        Health Care  NASDAQ
#  996   997      Clyde          Fyfe   BLBD      Capital Goods  NASDAQ
#  997   998    Rosalia      Zuanazzi    ETJ                NaN    NYSE
#  998   999       Rena     Hovington   JNCE        Health Care  NASDAQ
#  999  1000     Revkah     Flockhart   DRWI   Public Utilities  NASDAQ
#
#                                              Stock Name Market Cap  \
#  0                                         Luby's, Inc.    $88.73M
#  1                    North European Oil Royality Trust    $61.21M
#  2                            The Rubicon Project, Inc.   $275.01M
#  3                                     PhotoMedex, Inc.     $6.29M
#  4                                Lombard Medical, Inc.    $13.04M
#  ..                                                 ...        ...
#  995                        Oxford Immunotec Global PLC   $344.13M
#  996                              Blue Bird Corporation    $420.7M
#  997  Eaton Vance Risk-Managed Diversified Equity In...   $601.02M
#  998                          Jounce Therapeutics, Inc.   $498.65M
#  999                                     DragonWave Inc     $7.23M
#
#      Purchase Price                                  file date
#  0        $44389.17  Preppin Data Inputs/Input/MOCK_DATA-3.csv
#  1        $60710.96  Preppin Data Inputs/Input/MOCK_DATA-3.csv
#  2        $10714.77  Preppin Data Inputs/Input/MOCK_DATA-3.csv
#  3        $17801.56  Preppin Data Inputs/Input/MOCK_DATA-3.csv
#  4        $29170.58  Preppin Data Inputs/Input/MOCK_DATA-3.csv
#  ..             ...                                        ...
#  995      $74208.39  Preppin Data Inputs/Input/MOCK_DATA-3.csv
#  996      $77375.02  Preppin Data Inputs/Input/MOCK_DATA-3.csv
#  997      $12644.53  Preppin Data Inputs/Input/MOCK_DATA-3.csv
#  998      $85274.44  Preppin Data Inputs/Input/MOCK_DATA-3.csv
#  999      $76222.36  Preppin Data Inputs/Input/MOCK_DATA-3.csv
#
#  [1000 rows x 10 columns],
#         id  first_name last_name Ticker                 Sector  Market  \
#  0       1       Sybyl    Huxley   TMUS       Public Utilities  NASDAQ
#  1       2       Perle    Scarfe   RELL  Consumer Non-Durables  NASDAQ
#  2       3  Montgomery   Paliser    RBS                Finance    NYSE
#  3       4     Kirstyn     Falco   TEGP       Public Utilities    NYSE
#  4       5    Eustacia       Rea   WILC  Consumer Non-Durables  NASDAQ
#  ..    ...         ...       ...    ...                    ...     ...
#  995   996        Liva    Bodman  WFC^T                    NaN    NYSE
#  996   997       Selle     Delap   VNCE      Consumer Services    NYSE
#  997   998      Marlin   Brimman   NCBS                Finance  NASDAQ
#  998   999        Cory    Coopey   SWIN                    NaN  NASDAQ
#  999  1000     Karlene  Breissan   PSET                    NaN  NASDAQ
#
#                                   Stock Name Market Cap Purchase Price  \
#  0                         T-Mobile US, Inc.    $52.45B      $38271.32
#  1              Richardson Electronics, Ltd.    $75.94M       $1431.02
#  2             Royal Bank Scotland plc (The)    $37.92B      $84657.21
#  3                   Tallgrass Energy GP, LP     $3.69B       $5030.66
#  4        G. Willi-Food International,  Ltd.    $92.42M      $21845.51
#  ..                                      ...        ...            ...
#  995                   Wells Fargo & Company        NaN      $30284.27
#  996                     Vince Holding Corp.    $22.24M      $43476.75
#  997                 Nicolet Bankshares Inc.   $479.19M      $57382.19
#  998  ALPS/Dorsey Wright Sector Momentum ETF     $6.79M      $28500.91
#  999       Principal Price Setters Index ETF     $7.24M      $17105.15
#
#                                       file date
#  0    Preppin Data Inputs/Input/MOCK_DATA-2.csv
#  1    Preppin Data Inputs/Input/MOCK_DATA-2.csv
#  2    Preppin Data Inputs/Input/MOCK_DATA-2.csv
#  3    Preppin Data Inputs/Input/MOCK_DATA-2.csv
#  4    Preppin Data Inputs/Input/MOCK_DATA-2.csv
#  ..                                         ...
#  995  Preppin Data Inputs/Input/MOCK_DATA-2.csv
#  996  Preppin Data Inputs/Input/MOCK_DATA-2.csv
#  997  Preppin Data Inputs/Input/MOCK_DATA-2.csv
#  998  Preppin Data Inputs/Input/MOCK_DATA-2.csv
#  999  Preppin Data Inputs/Input/MOCK_DATA-2.csv
#
#  [1000 rows x 10 columns],
#         id first_name   last_name Ticker                 Sector  Market  \
#  0       1      Vikki     Pascall    RIC       Basic Industries    NYSE
#  1       2     Beulah   Michallat    ELY  Consumer Non-Durables    NYSE
#  2       3     Mignon  Blenkinsop  CPTAG                    NaN  NASDAQ
#  3       4     Willis        Bugg    OAS                 Energy    NYSE
#  4       5    Balduin      Maffei   QQXT                    NaN  NASDAQ
#  ..    ...        ...         ...    ...                    ...     ...
#  995   996    Claudie      Greave    TJX      Consumer Services    NYSE
#  996   997    Sanford      Goakes   TITN      Consumer Services  NASDAQ
#  997   998    Renelle     Burford   STRM             Technology  NASDAQ
#  998   999  Matthaeus     Dannett   MH^C                    NaN    NYSE
#  999  1000      Joela      Disman   ESGD                    NaN  NASDAQ
#
#                                              Stock Name Market Cap  \
#  0                                 Richmont Mines, Inc.   $458.83M
#  1                                Callaway Golf Company     $1.14B
#  2                               Capitala Finance Corp.        NaN
#  3                                 Oasis Petroleum Inc.     $1.94B
#  4    First Trust NASDAQ-100 Ex-Technology Sector In...   $101.07M
#  ..                                                 ...        ...
#  995                          TJX Companies, Inc. (The)     $46.6B
#  996                               Titan Machinery Inc.   $403.05M
#  997                  Streamline Health Solutions, Inc.    $21.44M
#  998                              Maiden Holdings, Ltd.        NaN
#  999                iShares MSCI EAFE ESG Optimized ETF    $127.9M
#
#      Purchase Price                                   file date
#  0        $78924.65  Preppin Data Inputs/Input/MOCK_DATA-10.csv
#  1        $89818.72  Preppin Data Inputs/Input/MOCK_DATA-10.csv
#  2        $53160.64  Preppin Data Inputs/Input/MOCK_DATA-10.csv
#  3        $23636.92  Preppin Data Inputs/Input/MOCK_DATA-10.csv
#  4        $65979.23  Preppin Data Inputs/Input/MOCK_DATA-10.csv
#  ..             ...                                         ...
#  995      $40153.02  Preppin Data Inputs/Input/MOCK_DATA-10.csv
#  996      $31782.80  Preppin Data Inputs/Input/MOCK_DATA-10.csv
#  997       $4506.73  Preppin Data Inputs/Input/MOCK_DATA-10.csv
#  998      $67401.86  Preppin Data Inputs/Input/MOCK_DATA-10.csv
#  999      $87291.90  Preppin Data Inputs/Input/MOCK_DATA-10.csv
#
#  [1000 rows x 10 columns],
#         id first_name     last_name Ticker                 Sector  Market  \
#  0       1      Lamar       Ascraft    DLX      Consumer Durables    NYSE
#  1       2     Marlyn     Sparshett    SHG                Finance    NYSE
#  2       3     Corene       Clother    USB                Finance    NYSE
#  3       4   Catriona        Kirlin     MT       Basic Industries    NYSE
#  4       5     Cynthy       Cornuau    HRL  Consumer Non-Durables    NYSE
#  ..    ...        ...           ...    ...                    ...     ...
#  995   996   Wallache    MacTrustam    CCZ      Consumer Services    NYSE
#  996   997      Chadd      Kenforth   MBCN                Finance  NASDAQ
#  997   998   Vittoria      Comettoi    FPF                    NaN    NYSE
#  998   999     Gordon  MacCallester   KTOV            Health Care  NASDAQ
#  999  1000       Oren       Torresi  LEXEB      Consumer Services  NASDAQ
#
#                                              Stock Name Market Cap  \
#  0                                   Deluxe Corporation     $3.46B
#  1                       Shinhan Financial Group Co Ltd    $21.39B
#  2                                         U.S. Bancorp    $88.09B
#  3                                        ArcelorMittal    $20.56B
#  4                             Hormel Foods Corporation    $17.94B
#  ..                                                 ...        ...
#  995                                Comcast Corporation        NaN
#  996                             Middlefield Banc Corp.   $168.26M
#  997  First Trust Intermediate Duration Preferred & ...     $1.48B
#  998                Kitov Pharmaceuticals Holdings Ltd.    $13.99M
#  999                     Liberty Expedia Holdings, Inc.     $3.06B
#
#      Purchase Price                                   file date
#  0         $8446.64  Preppin Data Inputs/Input/MOCK_DATA-12.csv
#  1        $61127.85  Preppin Data Inputs/Input/MOCK_DATA-12.csv
#  2        $73511.98  Preppin Data Inputs/Input/MOCK_DATA-12.csv
#  3        $83949.26  Preppin Data Inputs/Input/MOCK_DATA-12.csv
#  4        $99994.59  Preppin Data Inputs/Input/MOCK_DATA-12.csv
#  ..             ...                                         ...
#  995      $25831.98  Preppin Data Inputs/Input/MOCK_DATA-12.csv
#  996      $62388.63  Preppin Data Inputs/Input/MOCK_DATA-12.csv
#  997      $46325.42  Preppin Data Inputs/Input/MOCK_DATA-12.csv
#  998      $40070.82  Preppin Data Inputs/Input/MOCK_DATA-12.csv
#  999         $42.56  Preppin Data Inputs/Input/MOCK_DATA-12.csv
#
#  [1000 rows x 10 columns],
#         id first_name   last_name Ticker                 Sector  Market  \
#  0       1       Kort     Dessent   AGTC            Health Care  NASDAQ
#  1       2       Liva      Konert    KCG                Finance    NYSE
#  2       3   Roderich     Bartrop   RAVE  Consumer Non-Durables  NASDAQ
#  3       4     Verney  Giacobillo    MMM            Health Care    NYSE
#  4       5    Hedwiga      Silley   GPRE       Basic Industries  NASDAQ
#  ..    ...        ...         ...    ...                    ...     ...
#  995   996      Niven    Jozefiak     DO                 Energy    NYSE
#  996   997      Robbi     Loalday   NTRS                Finance  NASDAQ
#  997   998      Tynan    Goodoune  NLY^C                    NaN    NYSE
#  998   999   Gabriela      Syvret   ATRA            Health Care  NASDAQ
#  999  1000     Brigid      Lesley   OBLN            Health Care  NASDAQ
#
#                                     Stock Name Market Cap Purchase Price  \
#  0    Applied Genetic Technologies Corporation    $91.32M      $70550.49
#  1                          KCG Holdings, Inc.     $1.35B      $15180.89
#  2                 Rave Restaurant Group, Inc.    $22.17M      $34718.71
#  3                                  3M Company   $127.36B      $96110.73
#  4                          Green Plains, Inc.   $868.22M      $17263.86
#  ..                                        ...        ...            ...
#  995           Diamond Offshore Drilling, Inc.     $1.61B      $78757.80
#  996                Northern Trust Corporation    $21.71B      $88228.71
#  997             Annaly Capital Management Inc        NaN      $63271.60
#  998               Atara Biotherapeutics, Inc.   $371.14M      $37633.38
#  999                 Obalon Therapeutics, Inc.   $184.04M      $24100.30
#
#                                       file date
#  0    Preppin Data Inputs/Input/MOCK_DATA-5.csv
#  1    Preppin Data Inputs/Input/MOCK_DATA-5.csv
#  2    Preppin Data Inputs/Input/MOCK_DATA-5.csv
#  3    Preppin Data Inputs/Input/MOCK_DATA-5.csv
#  4    Preppin Data Inputs/Input/MOCK_DATA-5.csv
#  ..                                         ...
#  995  Preppin Data Inputs/Input/MOCK_DATA-5.csv
#  996  Preppin Data Inputs/Input/MOCK_DATA-5.csv
#  997  Preppin Data Inputs/Input/MOCK_DATA-5.csv
#  998  Preppin Data Inputs/Input/MOCK_DATA-5.csv
#  999  Preppin Data Inputs/Input/MOCK_DATA-5.csv
#
#  [1000 rows x 10 columns],
#         id first_name   last_name Ticker                 Sector  Market  \
#  0       1     Hadley     Willets   AFMD            Health Care  NASDAQ
#  1       2      Cassi      Watson   SYMC             Technology  NASDAQ
#  2       3    Saundra      Koppen   BCOR             Technology  NASDAQ
#  3       4     Crista        Carr    GMS      Consumer Services    NYSE
#  4       5     Kenton     Glackin    ETH      Consumer Durables    NYSE
#  ..    ...        ...         ...    ...                    ...     ...
#  995   996     Cletus      Joseff    TLF  Consumer Non-Durables  NASDAQ
#  996   997        Tod  Blandamore   SNAK  Consumer Non-Durables  NASDAQ
#  997   998      Maire     Bourdas    SNC                Finance  NASDAQ
#  998   999     Cullin   Adolphine   BVSN             Technology  NASDAQ
#  999  1000    Everett     Grinter  FCE.A                    NaN    NYSE
#
#                           Stock Name Market Cap Purchase Price  \
#  0                      Affimed N.V.    $87.88M      $99959.38
#  1              Symantec Corporation     $17.3B      $12069.06
#  2                     Blucora, Inc.   $909.02M      $85281.32
#  3                          GMS Inc.     $1.31B      $59157.56
#  4        Ethan Allen Interiors Inc.   $822.58M      $10163.50
#  ..                              ...        ...            ...
#  995     Tandy Leather Factory, Inc.    $76.52M      $72741.97
#  996           Inventure Foods, Inc.    $83.67M      $36102.07
#  997  State National Companies, Inc.   $736.77M      $52429.57
#  998               BroadVision, Inc.     $21.6M      $90267.53
#  999  Forest City Realty Trust, Inc.        NaN      $28831.60
#
#                                       file date
#  0    Preppin Data Inputs/Input/MOCK_DATA-4.csv
#  1    Preppin Data Inputs/Input/MOCK_DATA-4.csv
#  2    Preppin Data Inputs/Input/MOCK_DATA-4.csv
#  3    Preppin Data Inputs/Input/MOCK_DATA-4.csv
#  4    Preppin Data Inputs/Input/MOCK_DATA-4.csv
#  ..                                         ...
#  995  Preppin Data Inputs/Input/MOCK_DATA-4.csv
#  996  Preppin Data Inputs/Input/MOCK_DATA-4.csv
#  997  Preppin Data Inputs/Input/MOCK_DATA-4.csv
#  998  Preppin Data Inputs/Input/MOCK_DATA-4.csv
#  999  Preppin Data Inputs/Input/MOCK_DATA-4.csv
#
#  [1000 rows x 10 columns],
#         id first_name     last_name Ticker             Sector  Market  \
#  0       1     Godfry        Server   MANH         Technology  NASDAQ
#  1       2     Feliza  Degli Antoni   EBTC            Finance  NASDAQ
#  2       3   Kathryne          Juza   ATLC            Finance  NASDAQ
#  3       4      Jessa         Kwiek  INN^C                NaN    NYSE
#  4       5     Reggie       Guillon    SSW     Transportation    NYSE
#  ..    ...        ...           ...    ...                ...     ...
#  995   996     Kalvin      Concklin    RSO  Consumer Services    NYSE
#  996   997      Ryann       Stuther    CHH  Consumer Services    NYSE
#  997   998      Minne      Sleeford    RTK   Basic Industries  NASDAQ
#  998   999    Lammond         Lunam   BHBK            Finance  NASDAQ
#  999  1000     Kennan      Bloschke    RFP   Basic Industries    NYSE
#
#                              Stock Name Market Cap Purchase Price  \
#  0           Manhattan Associates, Inc.     $3.27B      $20026.38
#  1               Enterprise Bancorp Inc   $414.73M      $51187.25
#  2      Atlanticus Holdings Corporation    $35.52M      $78066.43
#  3        Summit Hotel Properties, Inc.        NaN      $91989.49
#  4                  Seaspan Corporation   $649.92M      $53999.77
#  ..                                 ...        ...            ...
#  995             Resource Capital Corp.   $316.71M      $30174.18
#  996  Choice Hotels International, Inc.     $3.75B      $77149.68
#  997                      Rentech, Inc.    $10.31M      $95598.40
#  998           Blue Hills Bancorp, Inc.   $476.74M      $12190.54
#  999      Resolute Forest Products Inc.   $413.36M      $15104.46
#
#                                       file date
#  0    Preppin Data Inputs/Input/MOCK_DATA-6.csv
#  1    Preppin Data Inputs/Input/MOCK_DATA-6.csv
#  2    Preppin Data Inputs/Input/MOCK_DATA-6.csv
#  3    Preppin Data Inputs/Input/MOCK_DATA-6.csv
#  4    Preppin Data Inputs/Input/MOCK_DATA-6.csv
#  ..                                         ...
#  995  Preppin Data Inputs/Input/MOCK_DATA-6.csv
#  996  Preppin Data Inputs/Input/MOCK_DATA-6.csv
#  997  Preppin Data Inputs/Input/MOCK_DATA-6.csv
#  998  Preppin Data Inputs/Input/MOCK_DATA-6.csv
#  999  Preppin Data Inputs/Input/MOCK_DATA-6.csv
#
#  [1000 rows x 10 columns],
#         id first_name   last_name Ticker             Sector  Market  \
#  0       1     Emilia      Massey  AFHBL            Finance  NASDAQ
#  1       2      Julee   Runnacles    BPL             Energy    NYSE
#  2       3      Burty       Fairy  PBI^B                NaN    NYSE
#  3       4      Gayel     Keigher   CYOU         Technology  NASDAQ
#  4       5    Bernard        Cadd   LBAI            Finance  NASDAQ
#  ..    ...        ...         ...    ...                ...     ...
#  995   996    Karissa    Ferriman    FNV   Basic Industries    NYSE
#  996   997      Angel       Sisse   PRQR        Health Care  NASDAQ
#  997   998      Nerti       Huitt    BXE             Energy    NYSE
#  998   999     Wenona   Glencross   CDOR  Consumer Services  NASDAQ
#  999  1000      Drusi  Barneville    BKD        Health Care    NYSE
#
#                           Stock Name Market Cap Purchase Price  \
#  0    Atlas Financial Holdings, Inc.        NaN      $60495.22
#  1             Buckeye Partners L.P.     $8.62B      $74395.94
#  2                 Pitney Bowes Inc.        NaN      $22159.23
#  3              Changyou.com Limited     $2.05B      $76973.64
#  4            Lakeland Bancorp, Inc.   $937.55M      $80423.62
#  ..                              ...        ...            ...
#  995       Franco-Nevada Corporation    $12.86B      $90797.13
#  996         ProQR Therapeutics N.V.   $118.13M      $10199.10
#  997       Bellatrix Exploration Ltd   $152.93M      $93024.65
#  998  Condor Hospitality Trust, Inc.    $121.9M      $71870.15
#  999    Brookdale Senior Living Inc.     $2.76B      $63714.43
#
#                                       file date
#  0    Preppin Data Inputs/Input/MOCK_DATA-7.csv
#  1    Preppin Data Inputs/Input/MOCK_DATA-7.csv
#  2    Preppin Data Inputs/Input/MOCK_DATA-7.csv
#  3    Preppin Data Inputs/Input/MOCK_DATA-7.csv
#  4    Preppin Data Inputs/Input/MOCK_DATA-7.csv
#  ..                                         ...
#  995  Preppin Data Inputs/Input/MOCK_DATA-7.csv
#  996  Preppin Data Inputs/Input/MOCK_DATA-7.csv
#  997  Preppin Data Inputs/Input/MOCK_DATA-7.csv
#  998  Preppin Data Inputs/Input/MOCK_DATA-7.csv
#  999  Preppin Data Inputs/Input/MOCK_DATA-7.csv
#
#  [1000 rows x 10 columns],
#         id first_name    last_name Ticker             Sector  Market  \
#  0       1      Elfie        Eyton    LYB   Basic Industries    NYSE
#  1       2   Jeannine   Simoneschi   DLBL            Finance  NASDAQ
#  2       3       Alan    Antonioni   GMTA  Consumer Services    NYSE
#  3       4    Rogerio         Cran   CTHR  Consumer Durables  NASDAQ
#  4       5      Ollie    Woodhouse    CXH                NaN    NYSE
#  ..    ...        ...          ...    ...                ...     ...
#  995   996    Mirelle       Wodham  AIV^A                NaN    NYSE
#  996   997        Lay      McBryde   WASH            Finance  NASDAQ
#  997   998    Melania      Anstead    MEI      Capital Goods    NYSE
#  998   999       Baxy  Matiashvili    LEA      Capital Goods    NYSE
#  999  1000      Fayre      Gwalter   VRNS         Technology  NASDAQ
#
#                                        Stock Name Market Cap Purchase Price  \
#  0                   LyondellBasell Industries NV    $32.58B       $6602.67
#  1           iPath US Treasury Long Bond Bull ETN      $5.4M      $40844.29
#  2                               GATX Corporation        NaN       $6800.48
#  3                          Charles & Colvard Ltd    $19.68M      $97881.35
#  4      Colonial Investment Grade Municipal Trust   $116.91M      $13516.32
#  ..                                           ...        ...            ...
#  995  Apartment Investment and Management Company        NaN      $78403.43
#  996               Washington Trust Bancorp, Inc.   $872.35M       $4217.59
#  997                    Methode Electronics, Inc.      $1.5B      $12447.51
#  998                             Lear Corporation     $9.54B      $81977.75
#  999                        Varonis Systems, Inc.   $975.72M      $38802.75
#
#                                       file date
#  0    Preppin Data Inputs/Input/MOCK_DATA-9.csv
#  1    Preppin Data Inputs/Input/MOCK_DATA-9.csv
#  2    Preppin Data Inputs/Input/MOCK_DATA-9.csv
#  3    Preppin Data Inputs/Input/MOCK_DATA-9.csv
#  4    Preppin Data Inputs/Input/MOCK_DATA-9.csv
#  ..                                         ...
#  995  Preppin Data Inputs/Input/MOCK_DATA-9.csv
#  996  Preppin Data Inputs/Input/MOCK_DATA-9.csv
#  997  Preppin Data Inputs/Input/MOCK_DATA-9.csv
#  998  Preppin Data Inputs/Input/MOCK_DATA-9.csv
#  999  Preppin Data Inputs/Input/MOCK_DATA-9.csv
#
#  [1000 rows x 10 columns],
#         id first_name    last_name Ticker             Sector  Market  \
#  0       1        Isa      Kinsley    UHS        Health Care    NYSE
#  1       2      Udale      Pentony    KTP            Finance    NYSE
#  2       3    Emeline  Paulitschke  ANH^B                NaN    NYSE
#  3       4      Cesar       Heugle    EAE   Public Utilities    NYSE
#  4       5   Claudius       Heinel   MFSF            Finance  NASDAQ
#  ..    ...        ...          ...    ...                ...     ...
#  995   996      Brant     Schwartz   BCBP            Finance  NASDAQ
#  996   997      Terry   Leindecker    XIN   Basic Industries    NYSE
#  997   998   Zaccaria     Slatcher   ADBE         Technology  NASDAQ
#  998   999   Gayelord    Blenkhorn    AOI  Consumer Services    NYSE
#  999  1000        Ced      Desbrow    CBM        Health Care    NYSE
#
#                                Stock Name Market Cap Purchase Price  \
#  0        Universal Health Services, Inc.    $11.13B      $30593.11
#  1                 Lehman ABS Corporation        NaN      $49111.63
#  2    Anworth Mortgage Asset  Corporation        NaN      $99630.72
#  3                 Entergy Arkansas, Inc.        NaN      $21327.40
#  4             MutualFirst Financial Inc.   $256.68M      $29775.40
#  ..                                   ...        ...            ...
#  995               BCB Bancorp, Inc. (NJ)   $174.42M      $94153.43
#  996           Xinyuan Real Estate Co Ltd    $317.4M      $21159.77
#  997           Adobe Systems Incorporated    $68.19B      $28113.08
#  998     Alliance One International, Inc.   $134.83M      $84451.49
#  999                  Cambrex Corporation     $1.87B      $95679.27
#
#                                       file date
#  0    Preppin Data Inputs/Input/MOCK_DATA-8.csv
#  1    Preppin Data Inputs/Input/MOCK_DATA-8.csv
#  2    Preppin Data Inputs/Input/MOCK_DATA-8.csv
#  3    Preppin Data Inputs/Input/MOCK_DATA-8.csv
#  4    Preppin Data Inputs/Input/MOCK_DATA-8.csv
#  ..                                         ...
#  995  Preppin Data Inputs/Input/MOCK_DATA-8.csv
#  996  Preppin Data Inputs/Input/MOCK_DATA-8.csv
#  997  Preppin Data Inputs/Input/MOCK_DATA-8.csv
#  998  Preppin Data Inputs/Input/MOCK_DATA-8.csv
#  999  Preppin Data Inputs/Input/MOCK_DATA-8.csv
#
#  [1000 rows x 10 columns]]

# %%
df = pd.concat(df_list, ignore_index=True)

# %%
def month(file_date):
    if '12' in file_date:
        return 'December'
    elif '11' in file_date:
        return 'November'
    elif '10' in file_date:
        return 'October'
    elif '9' in file_date:
        return 'September'
    elif '8' in file_date:
        return 'August'
    elif '7' in file_date:
        return 'July'
    elif '6' in file_date:
        return 'June'
    elif '5' in file_date:
        return 'May'
    elif '4' in file_date:
        return 'April'
    elif '3' in file_date:
        return 'March'
    elif '2' in file_date:
        return 'February'
    else:
        return 'January'

# %%
df['file date'] = df['file date'].apply(month)

# %%
df['file date'] = pd.to_datetime(df['file date'] + ' 2023',format='%B %Y')

# %%
df
# Out:
#          id first_name   last_name Ticker             Sector  Market  \
# 0         1      Hinze      Bartak  CYRXW     Transportation  NASDAQ
# 1         2      Lelia     Gresley   GILD        Health Care  NASDAQ
# 2         3  Leicester        Roff    NMZ                NaN    NYSE
# 3         4       Baxy     Fieller  USB^A            Finance    NYSE
# 4         5     Julita   Spradbery   INSI                NaN    NYSE
# ...     ...        ...         ...    ...                ...     ...
# 11995   996      Brant    Schwartz   BCBP            Finance  NASDAQ
# 11996   997      Terry  Leindecker    XIN   Basic Industries    NYSE
# 11997   998   Zaccaria    Slatcher   ADBE         Technology  NASDAQ
# 11998   999   Gayelord   Blenkhorn    AOI  Consumer Services    NYSE
# 11999  1000        Ced     Desbrow    CBM        Health Care    NYSE
#
#                                           Stock Name Market Cap  \
# 0                                     CryoPort, Inc.        NaN
# 1                              Gilead Sciences, Inc.    $83.79B
# 2      Nuveen Municipal High Income Opportunity Fund   $794.98M
# 3                                       U.S. Bancorp        NaN
# 4                         Insight Select Income Fund   $211.52M
# ...                                              ...        ...
# 11995                         BCB Bancorp, Inc. (NJ)   $174.42M
# 11996                     Xinyuan Real Estate Co Ltd    $317.4M
# 11997                     Adobe Systems Incorporated    $68.19B
# 11998               Alliance One International, Inc.   $134.83M
# 11999                            Cambrex Corporation     $1.87B
#
#       Purchase Price  file date
# 0           $6947.28 2023-01-01
# 1          $77627.18 2023-01-01
# 2          $40676.73 2023-01-01
# 3          $42441.50 2023-01-01
# 4          $41908.66 2023-01-01
# ...              ...        ...
# 11995      $94153.43 2023-08-01
# 11996      $21159.77 2023-08-01
# 11997      $28113.08 2023-08-01
# 11998      $84451.49 2023-08-01
# 11999      $95679.27 2023-08-01
#
# [12000 rows x 10 columns]

# %% [markdown]
# 3. Clean the Market Cap value to ensure it is the true value as 'Market Capitalisation'. Remove any rows with 'n/a'

# %%
df = df.dropna(subset='Market Cap')

# %%
df
# Out:
#          id first_name   last_name Ticker             Sector  Market  \
# 1         2      Lelia     Gresley   GILD        Health Care  NASDAQ
# 2         3  Leicester        Roff    NMZ                NaN    NYSE
# 4         5     Julita   Spradbery   INSI                NaN    NYSE
# 5         6     Steven     McGrale     AP      Capital Goods    NYSE
# 7         8       Elly        Dono    SCM                NaN    NYSE
# ...     ...        ...         ...    ...                ...     ...
# 11995   996      Brant    Schwartz   BCBP            Finance  NASDAQ
# 11996   997      Terry  Leindecker    XIN   Basic Industries    NYSE
# 11997   998   Zaccaria    Slatcher   ADBE         Technology  NASDAQ
# 11998   999   Gayelord   Blenkhorn    AOI  Consumer Services    NYSE
# 11999  1000        Ced     Desbrow    CBM        Health Care    NYSE
#
#                                           Stock Name Market Cap  \
# 1                              Gilead Sciences, Inc.    $83.79B
# 2      Nuveen Municipal High Income Opportunity Fund   $794.98M
# 4                         Insight Select Income Fund   $211.52M
# 5                       Ampco-Pittsburgh Corporation   $175.48M
# 7             Stellus Capital Investment Corporation   $213.68M
# ...                                              ...        ...
# 11995                         BCB Bancorp, Inc. (NJ)   $174.42M
# 11996                     Xinyuan Real Estate Co Ltd    $317.4M
# 11997                     Adobe Systems Incorporated    $68.19B
# 11998               Alliance One International, Inc.   $134.83M
# 11999                            Cambrex Corporation     $1.87B
#
#       Purchase Price  file date
# 1          $77627.18 2023-01-01
# 2          $40676.73 2023-01-01
# 4          $41908.66 2023-01-01
# 5            $163.84 2023-01-01
# 7          $55985.51 2023-01-01
# ...              ...        ...
# 11995      $94153.43 2023-08-01
# 11996      $21159.77 2023-08-01
# 11997      $28113.08 2023-08-01
# 11998      $84451.49 2023-08-01
# 11999      $95679.27 2023-08-01
#
# [10109 rows x 10 columns]

# %%
df.loc[:, 'Market Cap'] = df['Market Cap'].str.replace('$','')

# %%
df
# Out:
#          id first_name   last_name Ticker             Sector  Market  \
# 1         2      Lelia     Gresley   GILD        Health Care  NASDAQ
# 2         3  Leicester        Roff    NMZ                NaN    NYSE
# 4         5     Julita   Spradbery   INSI                NaN    NYSE
# 5         6     Steven     McGrale     AP      Capital Goods    NYSE
# 7         8       Elly        Dono    SCM                NaN    NYSE
# ...     ...        ...         ...    ...                ...     ...
# 11995   996      Brant    Schwartz   BCBP            Finance  NASDAQ
# 11996   997      Terry  Leindecker    XIN   Basic Industries    NYSE
# 11997   998   Zaccaria    Slatcher   ADBE         Technology  NASDAQ
# 11998   999   Gayelord   Blenkhorn    AOI  Consumer Services    NYSE
# 11999  1000        Ced     Desbrow    CBM        Health Care    NYSE
#
#                                           Stock Name Market Cap  \
# 1                              Gilead Sciences, Inc.     83.79B
# 2      Nuveen Municipal High Income Opportunity Fund    794.98M
# 4                         Insight Select Income Fund    211.52M
# 5                       Ampco-Pittsburgh Corporation    175.48M
# 7             Stellus Capital Investment Corporation    213.68M
# ...                                              ...        ...
# 11995                         BCB Bancorp, Inc. (NJ)    174.42M
# 11996                     Xinyuan Real Estate Co Ltd     317.4M
# 11997                     Adobe Systems Incorporated     68.19B
# 11998               Alliance One International, Inc.    134.83M
# 11999                            Cambrex Corporation      1.87B
#
#       Purchase Price  file date
# 1          $77627.18 2023-01-01
# 2          $40676.73 2023-01-01
# 4          $41908.66 2023-01-01
# 5            $163.84 2023-01-01
# 7          $55985.51 2023-01-01
# ...              ...        ...
# 11995      $94153.43 2023-08-01
# 11996      $21159.77 2023-08-01
# 11997      $28113.08 2023-08-01
# 11998      $84451.49 2023-08-01
# 11999      $95679.27 2023-08-01
#
# [10109 rows x 10 columns]

# %%
def true_value(x):
    if 'M' in x:
        y = x.replace('M','')
        return float(y) * 1000000
    else:
        y = x.replace('B','')
        return float(y) * 1000000000

# %%
df.loc[:, 'Market Cap'] = df['Market Cap'].apply(true_value)

# %%
df = df.rename(columns={'Market Cap':'Market Capitalisation'})

# %%
df
# Out:
#          id first_name   last_name Ticker             Sector  Market  \
# 1         2      Lelia     Gresley   GILD        Health Care  NASDAQ
# 2         3  Leicester        Roff    NMZ                NaN    NYSE
# 4         5     Julita   Spradbery   INSI                NaN    NYSE
# 5         6     Steven     McGrale     AP      Capital Goods    NYSE
# 7         8       Elly        Dono    SCM                NaN    NYSE
# ...     ...        ...         ...    ...                ...     ...
# 11995   996      Brant    Schwartz   BCBP            Finance  NASDAQ
# 11996   997      Terry  Leindecker    XIN   Basic Industries    NYSE
# 11997   998   Zaccaria    Slatcher   ADBE         Technology  NASDAQ
# 11998   999   Gayelord   Blenkhorn    AOI  Consumer Services    NYSE
# 11999  1000        Ced     Desbrow    CBM        Health Care    NYSE
#
#                                           Stock Name Market Capitalisation  \
# 1                              Gilead Sciences, Inc.         83790000000.0
# 2      Nuveen Municipal High Income Opportunity Fund           794980000.0
# 4                         Insight Select Income Fund           211520000.0
# 5                       Ampco-Pittsburgh Corporation           175480000.0
# 7             Stellus Capital Investment Corporation           213680000.0
# ...                                              ...                   ...
# 11995                         BCB Bancorp, Inc. (NJ)           174420000.0
# 11996                     Xinyuan Real Estate Co Ltd           317400000.0
# 11997                     Adobe Systems Incorporated         68190000000.0
# 11998               Alliance One International, Inc.           134830000.0
# 11999                            Cambrex Corporation          1870000000.0
#
#       Purchase Price  file date
# 1          $77627.18 2023-01-01
# 2          $40676.73 2023-01-01
# 4          $41908.66 2023-01-01
# 5            $163.84 2023-01-01
# 7          $55985.51 2023-01-01
# ...              ...        ...
# 11995      $94153.43 2023-08-01
# 11996      $21159.77 2023-08-01
# 11997      $28113.08 2023-08-01
# 11998      $84451.49 2023-08-01
# 11999      $95679.27 2023-08-01
#
# [10109 rows x 10 columns]

# %% [markdown]
# 4. Categorise the Purchase Price into groupings: 0 to 24,999.99 as 'Low', 25,000 to 49,999.99 as 'Medium', 50,000 to 74,999.99 as 'High', 75,000 to 100,000 as 'Very High'

# %%
def purchase_price_cat(x):

    y = x.replace('$','')

    y = float(y)
    
    if y >= 0 and y <= 24999.99:
        return 'Low'
    elif y >= 25000 and y <= 49999.99:
        return 'Medium'
    elif y >= 50000 and y <= 74999.99:
        return 'High'
    else:
        return 'Very High'

# %%
df['Purchase Price Category'] = df['Purchase Price'].apply(purchase_price_cat)

# %%
df
# Out:
#          id first_name   last_name Ticker             Sector  Market  \
# 1         2      Lelia     Gresley   GILD        Health Care  NASDAQ
# 2         3  Leicester        Roff    NMZ                NaN    NYSE
# 4         5     Julita   Spradbery   INSI                NaN    NYSE
# 5         6     Steven     McGrale     AP      Capital Goods    NYSE
# 7         8       Elly        Dono    SCM                NaN    NYSE
# ...     ...        ...         ...    ...                ...     ...
# 11995   996      Brant    Schwartz   BCBP            Finance  NASDAQ
# 11996   997      Terry  Leindecker    XIN   Basic Industries    NYSE
# 11997   998   Zaccaria    Slatcher   ADBE         Technology  NASDAQ
# 11998   999   Gayelord   Blenkhorn    AOI  Consumer Services    NYSE
# 11999  1000        Ced     Desbrow    CBM        Health Care    NYSE
#
#                                           Stock Name Market Capitalisation  \
# 1                              Gilead Sciences, Inc.         83790000000.0
# 2      Nuveen Municipal High Income Opportunity Fund           794980000.0
# 4                         Insight Select Income Fund           211520000.0
# 5                       Ampco-Pittsburgh Corporation           175480000.0
# 7             Stellus Capital Investment Corporation           213680000.0
# ...                                              ...                   ...
# 11995                         BCB Bancorp, Inc. (NJ)           174420000.0
# 11996                     Xinyuan Real Estate Co Ltd           317400000.0
# 11997                     Adobe Systems Incorporated         68190000000.0
# 11998               Alliance One International, Inc.           134830000.0
# 11999                            Cambrex Corporation          1870000000.0
#
#       Purchase Price  file date Purchase Price Category
# 1          $77627.18 2023-01-01               Very High
# 2          $40676.73 2023-01-01                  Medium
# 4          $41908.66 2023-01-01                  Medium
# 5            $163.84 2023-01-01                     Low
# 7          $55985.51 2023-01-01                    High
# ...              ...        ...                     ...
# 11995      $94153.43 2023-08-01               Very High
# 11996      $21159.77 2023-08-01                     Low
# 11997      $28113.08 2023-08-01                  Medium
# 11998      $84451.49 2023-08-01               Very High
# 11999      $95679.27 2023-08-01               Very High
#
# [10109 rows x 11 columns]

# %% [markdown]
# 5. Categorise the Market Cap into groupings: Below 100M as 'Small', Between 100M and below 1B as 'Medium', Between 1B and below 100B as 'Large', 100B and above as 'Huge'

# %%
def market_cap_cat(x):
    if x < 100000000:
        return 'Small'
    elif x >= 100000000 and x < 1000000000:
        return 'Medium'
    elif x >= 1000000000 and x < 100000000000:
        return 'Large'
    else:
        return ' Huge'

# %%
df['Market Capitalisation Category'] = df['Market Capitalisation'].apply(market_cap_cat)

# %%
df
# Out:
#          id first_name   last_name Ticker             Sector  Market  \
# 1         2      Lelia     Gresley   GILD        Health Care  NASDAQ
# 2         3  Leicester        Roff    NMZ                NaN    NYSE
# 4         5     Julita   Spradbery   INSI                NaN    NYSE
# 5         6     Steven     McGrale     AP      Capital Goods    NYSE
# 7         8       Elly        Dono    SCM                NaN    NYSE
# ...     ...        ...         ...    ...                ...     ...
# 11995   996      Brant    Schwartz   BCBP            Finance  NASDAQ
# 11996   997      Terry  Leindecker    XIN   Basic Industries    NYSE
# 11997   998   Zaccaria    Slatcher   ADBE         Technology  NASDAQ
# 11998   999   Gayelord   Blenkhorn    AOI  Consumer Services    NYSE
# 11999  1000        Ced     Desbrow    CBM        Health Care    NYSE
#
#                                           Stock Name Market Capitalisation  \
# 1                              Gilead Sciences, Inc.         83790000000.0
# 2      Nuveen Municipal High Income Opportunity Fund           794980000.0
# 4                         Insight Select Income Fund           211520000.0
# 5                       Ampco-Pittsburgh Corporation           175480000.0
# 7             Stellus Capital Investment Corporation           213680000.0
# ...                                              ...                   ...
# 11995                         BCB Bancorp, Inc. (NJ)           174420000.0
# 11996                     Xinyuan Real Estate Co Ltd           317400000.0
# 11997                     Adobe Systems Incorporated         68190000000.0
# 11998               Alliance One International, Inc.           134830000.0
# 11999                            Cambrex Corporation          1870000000.0
#
#       Purchase Price  file date Purchase Price Category  \
# 1          $77627.18 2023-01-01               Very High
# 2          $40676.73 2023-01-01                  Medium
# 4          $41908.66 2023-01-01                  Medium
# 5            $163.84 2023-01-01                     Low
# 7          $55985.51 2023-01-01                    High
# ...              ...        ...                     ...
# 11995      $94153.43 2023-08-01               Very High
# 11996      $21159.77 2023-08-01                     Low
# 11997      $28113.08 2023-08-01                  Medium
# 11998      $84451.49 2023-08-01               Very High
# 11999      $95679.27 2023-08-01               Very High
#
#       Market Capitalisation Category
# 1                              Large
# 2                             Medium
# 4                             Medium
# 5                             Medium
# 7                             Medium
# ...                              ...
# 11995                         Medium
# 11996                         Medium
# 11997                          Large
# 11998                         Medium
# 11999                          Large
#
# [10109 rows x 12 columns]

# %% [markdown]
# 6. Rank the highest 5 purchases per combination of: file date, Purchase Price Categorisation and Market Capitalisation Categorisation.

# %%
df['Purchase Price'] = df['Purchase Price'].str.replace('$','')

# %%
df['Purchase Price'] = df['Purchase Price'].astype(float)

# %%
df['rank'] = df.groupby(['file date','Purchase Price Category','Market Capitalisation Category'])['Purchase Price'].rank(method='dense',ascending=False)

# %%
df
# Out:
#          id first_name   last_name Ticker             Sector  Market  \
# 1         2      Lelia     Gresley   GILD        Health Care  NASDAQ
# 2         3  Leicester        Roff    NMZ                NaN    NYSE
# 4         5     Julita   Spradbery   INSI                NaN    NYSE
# 5         6     Steven     McGrale     AP      Capital Goods    NYSE
# 7         8       Elly        Dono    SCM                NaN    NYSE
# ...     ...        ...         ...    ...                ...     ...
# 11995   996      Brant    Schwartz   BCBP            Finance  NASDAQ
# 11996   997      Terry  Leindecker    XIN   Basic Industries    NYSE
# 11997   998   Zaccaria    Slatcher   ADBE         Technology  NASDAQ
# 11998   999   Gayelord   Blenkhorn    AOI  Consumer Services    NYSE
# 11999  1000        Ced     Desbrow    CBM        Health Care    NYSE
#
#                                           Stock Name Market Capitalisation  \
# 1                              Gilead Sciences, Inc.         83790000000.0
# 2      Nuveen Municipal High Income Opportunity Fund           794980000.0
# 4                         Insight Select Income Fund           211520000.0
# 5                       Ampco-Pittsburgh Corporation           175480000.0
# 7             Stellus Capital Investment Corporation           213680000.0
# ...                                              ...                   ...
# 11995                         BCB Bancorp, Inc. (NJ)           174420000.0
# 11996                     Xinyuan Real Estate Co Ltd           317400000.0
# 11997                     Adobe Systems Incorporated         68190000000.0
# 11998               Alliance One International, Inc.           134830000.0
# 11999                            Cambrex Corporation          1870000000.0
#
#        Purchase Price  file date Purchase Price Category  \
# 1            77627.18 2023-01-01               Very High
# 2            40676.73 2023-01-01                  Medium
# 4            41908.66 2023-01-01                  Medium
# 5              163.84 2023-01-01                     Low
# 7            55985.51 2023-01-01                    High
# ...               ...        ...                     ...
# 11995        94153.43 2023-08-01               Very High
# 11996        21159.77 2023-08-01                     Low
# 11997        28113.08 2023-08-01                  Medium
# 11998        84451.49 2023-08-01               Very High
# 11999        95679.27 2023-08-01               Very High
#
#       Market Capitalisation Category  rank
# 1                              Large  90.0
# 2                             Medium  28.0
# 4                             Medium  25.0
# 5                             Medium  74.0
# 7                             Medium  62.0
# ...                              ...   ...
# 11995                         Medium  18.0
# 11996                         Medium   8.0
# 11997                          Large  69.0
# 11998                         Medium  53.0
# 11999                          Large   8.0
#
# [10109 rows x 13 columns]

# %%
top_5_df = df[df['rank'] <= 5.0]

# %%
top_5_df
# Out:
#         id first_name  last_name          Ticker            Sector  Market  \
# 13      14    Erminie        Lis             JHD               NaN    NYSE
# 21      22      Davin    Rusling            LINK        Technology  NASDAQ
# 53      54       Jany     Hancke            CSOD        Technology  NASDAQ
# 106    107      Chico   De Maria  CBA                          NaN    NYSE
# 119    120    Nealson    Hosburn            VSTM       Health Care  NASDAQ
# ...    ...        ...        ...             ...               ...     ...
# 11965  966     Denney    Manvell             IDE               NaN    NYSE
# 11967  968    Cecilio  Itzkowicz             BSM            Energy    NYSE
# 11972  973      Carry       Buff            ONCE       Health Care  NASDAQ
# 11973  974       Babs   Surcombe            IDRA       Health Care  NASDAQ
# 11988  989        Ora     Berard             SEP  Public Utilities    NYSE
#
#                                               Stock Name  \
# 13     Nuveen High Income December 2019 Target Term Fund
# 21                           Interlink Electronics, Inc.
# 53                            Cornerstone OnDemand, Inc.
# 106            ClearBridge American Energy MLP Fund Inc.
# 119                                       Verastem, Inc.
# ...                                                  ...
# 11965  Voya Infrastructure, Industrials and Materials...
# 11967                         Black Stone Minerals, L.P.
# 11972                           Spark Therapeutics, Inc.
# 11973                        Idera Pharmaceuticals, Inc.
# 11988                        Spectra Energy Partners, LP
#
#       Market Capitalisation  Purchase Price  file date  \
# 13              277100000.0        24418.39 2023-01-01
# 21               60660000.0        23502.42 2023-01-01
# 53             2090000000.0        74079.42 2023-01-01
# 106             508590000.0        48507.84 2023-01-01
# 119              74720000.0        74416.07 2023-01-01
# ...                     ...             ...        ...
# 11965           296890000.0        24036.38 2023-08-01
# 11967          3000000000.0        24381.90 2023-08-01
# 11972          1820000000.0        98247.23 2023-08-01
# 11973           237150000.0        72016.13 2023-08-01
# 11988         13130000000.0        24372.21 2023-08-01
#
#       Purchase Price Category Market Capitalisation Category  rank
# 13                        Low                         Medium   2.0
# 21                        Low                          Small   4.0
# 53                       High                          Large   5.0
# 106                    Medium                         Medium   5.0
# 119                      High                          Small   3.0
# ...                       ...                            ...   ...
# 11965                     Low                         Medium   4.0
# 11967                     Low                          Large   1.0
# 11972               Very High                          Large   3.0
# 11973                    High                         Medium   4.0
# 11988                     Low                          Large   2.0
#
# [835 rows x 13 columns]

# %%
top_5_df = top_5_df.sort_values(by=['Purchase Price Category','Market Capitalisation Category','file date','rank'])

# %%
top_5_df
# Out:
#        id first_name   last_name Ticker                 Sector  Market  \
# 3794  795      Karon  Avramovitz    KHC  Consumer Non-Durables  NASDAQ
# 3620  621     Vallie     Rebeiro    DIS      Consumer Services    NYSE
# 2711  712   Angelina       Lotte   AAPL             Technology  NASDAQ
# 2161  162   Barnebas     Sapshed    SNY            Health Care    NYSE
# 2412  413      Phebe       McKew   MSFT             Technology  NASDAQ
# ...   ...        ...         ...    ...                    ...     ...
# 5352  353     Welbie      Robbey   ORMP            Health Care  NASDAQ
# 5117  118       Rice     Bentote    QAT                    NaN  NASDAQ
# 5664  665    Juditha  Bengefield   APEN            Health Care  NASDAQ
# 5958  959   Thomasin       Edmed   PTIE            Health Care  NASDAQ
# 5377  378    Chrissy      Daulby   ARTW          Capital Goods  NASDAQ
#
#                              Stock Name Market Capitalisation  Purchase Price  \
# 3794            The Kraft Heinz Company        108870000000.0        70939.69
# 3620          Walt Disney Company (The)        165110000000.0        64358.89
# 2711                         Apple Inc.        741770000000.0        72661.97
# 2161                             Sanofi        123340000000.0        71475.09
# 2412              Microsoft Corporation   540440000000.000061        64599.58
# ...                                 ...                   ...             ...
# 5352        Oramed Pharmaceuticals Inc.            98910000.0        99965.64
# 5117      iShares MSCI Qatar Capped ETF            38960000.0        99349.08
# 5664           Apollo Endosurgery, Inc.            72330000.0        98709.71
# 5958            Pain Therapeutics, Inc.            27030000.0        98696.95
# 5377  Art's-Way Manufacturing Co., Inc.            12260000.0        98615.62
#
#       file date Purchase Price Category Market Capitalisation Category  rank
# 3794 2023-02-01                    High                           Huge   1.0
# 3620 2023-02-01                    High                           Huge   2.0
# 2711 2023-03-01                    High                           Huge   1.0
# 2161 2023-03-01                    High                           Huge   2.0
# 2412 2023-03-01                    High                           Huge   3.0
# ...         ...                     ...                            ...   ...
# 5352 2023-12-01               Very High                          Small   1.0
# 5117 2023-12-01               Very High                          Small   2.0
# 5664 2023-12-01               Very High                          Small   3.0
# 5958 2023-12-01               Very High                          Small   4.0
# 5377 2023-12-01               Very High                          Small   5.0
#
# [835 rows x 13 columns]

# %%
top_5_df = top_5_df.iloc[:, [11,10,9,3,4,5,6,7,8,12]]

# %%
top_5_df
# Out:
#      Market Capitalisation Category Purchase Price Category  file date Ticker  \
# 3794                           Huge                    High 2023-02-01    KHC
# 3620                           Huge                    High 2023-02-01    DIS
# 2711                           Huge                    High 2023-03-01   AAPL
# 2161                           Huge                    High 2023-03-01    SNY
# 2412                           Huge                    High 2023-03-01   MSFT
# ...                             ...                     ...        ...    ...
# 5352                          Small               Very High 2023-12-01   ORMP
# 5117                          Small               Very High 2023-12-01    QAT
# 5664                          Small               Very High 2023-12-01   APEN
# 5958                          Small               Very High 2023-12-01   PTIE
# 5377                          Small               Very High 2023-12-01   ARTW
#
#                      Sector  Market                         Stock Name  \
# 3794  Consumer Non-Durables  NASDAQ            The Kraft Heinz Company
# 3620      Consumer Services    NYSE          Walt Disney Company (The)
# 2711             Technology  NASDAQ                         Apple Inc.
# 2161            Health Care    NYSE                             Sanofi
# 2412             Technology  NASDAQ              Microsoft Corporation
# ...                     ...     ...                                ...
# 5352            Health Care  NASDAQ        Oramed Pharmaceuticals Inc.
# 5117                    NaN  NASDAQ      iShares MSCI Qatar Capped ETF
# 5664            Health Care  NASDAQ           Apollo Endosurgery, Inc.
# 5958            Health Care  NASDAQ            Pain Therapeutics, Inc.
# 5377          Capital Goods  NASDAQ  Art's-Way Manufacturing Co., Inc.
#
#      Market Capitalisation  Purchase Price  rank
# 3794        108870000000.0        70939.69   1.0
# 3620        165110000000.0        64358.89   2.0
# 2711        741770000000.0        72661.97   1.0
# 2161        123340000000.0        71475.09   2.0
# 2412   540440000000.000061        64599.58   3.0
# ...                    ...             ...   ...
# 5352            98910000.0        99965.64   1.0
# 5117            38960000.0        99349.08   2.0
# 5664            72330000.0        98709.71   3.0
# 5958            27030000.0        98696.95   4.0
# 5377            12260000.0        98615.62   5.0
#
# [835 rows x 10 columns]

# %% [markdown]
# 7. Output only records with a rank of 1 to 5

# %%
top_5_df.to_csv('Preppin Data Outputs/pd2023wk8_output.csv', index=False)
